# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_Muster_0002.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "65 22 1292 170"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 65 22 1292 170" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "442 1855 880 1902"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 442 1855 880 1902" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b\d+\.\s\w+\s\d+\b", text)  # Search for a specific date format
    if match:
        date_text = match.group(0)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "89 2058 1246 2109"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 89 2058 1246 2109" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "89 2058 1246 2109"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 89 2058 1246 2109" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\.G\.[A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "194 373 1098 482"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 194 373 1098 482" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "442 529 854 585"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 442 529 854 585" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract heading 2 text from bounding box "328 638 971 746"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 328 638 971 746" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "523 886 781 927"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 523 886 781 927" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "120 964 1184 1246"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 120 964 1184 1246" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "451 1261 857 1312"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 451 1261 857 1312" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "166 1417 1146 1742"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 166 1417 1146 1742" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "442 1855 880 1902"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 442 1855 880 1902" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "89 2058 1246 2109"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 89 2058 1246 2109" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "1090 2162 1318 2202"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1090 2162 1318 2202" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract heading 3 text from bounding box "280 166 1579 255"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 280 166 1579 255" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract subheading 2 text from bounding box "645 273 1210 325"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 645 273 1210 325" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "279 373 1579 426"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 279 373 1579 426" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract heading 4 text from bounding box "275 608 1032 673"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 275 608 1032 673" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "209 694 1578 959"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 209 694 1578 959" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract heading 5 text from bounding box "271 1070 1571 1135"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 271 1070 1571 1135" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "196 1164 1575 2180"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 196 1164 1575 2180" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "260 2210 1080 2262"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 260 2210 1080 2262" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract heading 6 text from bounding box "271 149 1571 230"
div_h6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 271 149 1571 230" in value)
if div_h6:
    h6 = div_h6.get_text(strip=True)  # Extract text from the found div
else:
    h6 = ""  # Set h6 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "269 243 1572 345"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 269 243 1572 345" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "266 348 1576 673"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 266 348 1576 673" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "269 681 1637 915"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 269 681 1637 915" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract heading 7 text from bounding box "273 990 939 1045"
div_h7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 273 990 939 1045" in value)
if div_h7:
    h7 = div_h7.get_text(strip=True)  # Extract text from the found div
else:
    h7 = ""  # Set h7 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "323 1062 1579 1206"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 323 1062 1579 1206" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "325 1219 1582 1500"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 325 1219 1582 1500" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "323 1511 1582 1930"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 323 1511 1582 1930" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "322 1951 1587 2095"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 322 1951 1587 2095" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "328 2105 1588 2251"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 328 2105 1588 2251" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "311 169 1568 451"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 311 169 1568 451" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract subheading 8_0 text from bounding box "261 515 290 557"
div_h8_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 261 515 290 557" in value)
if div_h8_0:
    h8_0 = div_h8_0.get_text(strip=True)  # Extract text from the found div
else:
    h8_0 = ""  # Set h8_0 to empty string if the div is not found

# Extract heading 8 text from bounding box "315 509 855 564"
div_h8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 509 855 564" in value)
if div_h8:
    h8 = div_h8.get_text(strip=True)  # Extract text from the found div
else:
    h8 = ""  # Set h8 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "313 582 1568 861"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 582 1568 861" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "315 876 1569 1152"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 876 1569 1152" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "614 1166 1567 1264"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 614 1166 1567 1264" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "668 1276 1566 1374"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 668 1276 1566 1374" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "352 1407 1566 1526"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 352 1407 1566 1526" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "339 1513 1566 1583"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 339 1513 1566 1583" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "313 1569 1569 1722"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 1569 1569 1722" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "622 1750 1566 1849"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 622 1750 1566 1849" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found

# Extract paragraph 29 text from bounding box "667 1861 1566 1960"
div_p29 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 667 1861 1566 1960" in value)
if div_p29:
    p29 = div_p29.get_text(strip=True)  # Extract text from the found div
else:
    p29 = ""  # Set p29 to empty string if the div is not found

# Extract paragraph 30 text from bounding box "311 1985 1567 2265"
div_p30 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 311 1985 1567 2265" in value)
if div_p30:
    p30 = div_p30.get_text(strip=True)  # Extract text from the found div
else:
    p30 = ""  # Set p30 to empty string if the div is not found

# Extract paragraph 31 text from bounding box "323 160 1581 440"
div_p31 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 323 160 1581 440" in value)
if div_p31:
    p31 = div_p31.get_text(strip=True)  # Extract text from the found div
else:
    p31 = ""  # Set p31 to empty string if the div is not found

# Extract heading 9 text from bounding box "270 519 906 574"
div_h9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 270 519 906 574" in value)
if div_h9:
    h9 = div_h9.get_text(strip=True)  # Extract text from the found div
else:
    h9 = ""  # Set h9 to empty string if the div is not found

# Extract paragraph 32 text from bounding box "314 592 1636 1340"
div_p32 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 314 592 1636 1340" in value)
if div_p32:
    p32 = div_p32.get_text(strip=True)  # Extract text from the found div
else:
    p32 = ""  # Set p32 to empty string if the div is not found

# Extract paragraph 33 text from bounding box "315 1348 1570 1536"
div_p33 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 1348 1570 1536" in value)
if div_p33:
    p33 = div_p33.get_text(strip=True)  # Extract text from the found div
else:
    p33 = ""  # Set p33 to empty string if the div is not found

# Extract heading 10 text from bounding box "263 1616 1569 1724"
div_h10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 263 1616 1569 1724" in value)
if div_h10:
    h10 = div_h10.get_text(strip=True)  # Extract text from the found div
else:
    h10 = ""  # Set h10 to empty string if the div is not found

# Extract paragraph 34 text from bounding box "312 1737 1567 1972"
div_p34 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 312 1737 1567 1972" in value)
if div_p34:
    p34 = div_p34.get_text(strip=True)  # Extract text from the found div
else:
    p34 = ""  # Set p34 to empty string if the div is not found

# Extract paragraph 35 text from bounding box "306 1979 1569 2261"
div_p35 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 306 1979 1569 2261" in value)
if div_p35:
    p35 = div_p35.get_text(strip=True)  # Extract text from the found div
else:
    p35 = ""  # Set p35 to empty string if the div is not found

# Extract paragraph 36 text from bounding box "316 174 1571 361"
div_p36 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 316 174 1571 361" in value)
if div_p36:
    p36 = div_p36.get_text(strip=True)  # Extract text from the found div
else:
    p36 = ""  # Set p36 to empty string if the div is not found

# Extract paragraph 37 text from bounding box "310 370 1571 739"
div_p37 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 310 370 1571 739" in value)
if div_p37:
    p37 = div_p37.get_text(strip=True)  # Extract text from the found div
else:
    p37 = ""  # Set p37 to empty string if the div is not found

# Extract paragraph 38 text from bounding box "312 748 1570 935"
div_p38 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 312 748 1570 935" in value)
if div_p38:
    p38 = div_p38.get_text(strip=True)  # Extract text from the found div
else:
    p38 = ""  # Set p38 to empty string if the div is not found

# Extract subheading 11_0 text from bounding box "260 1028 301 1070"
div_h11_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 260 1028 301 1070" in value)
if div_h11_0:
    h11_0 = div_h11_0.get_text(strip=True)  # Extract text from the found div
else:
    h11_0 = ""  # Set h11_0 to empty string if the div is not found

# Extract heading 11 text from bounding box "313 1024 955 1075"
div_h11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 1024 955 1075" in value)
if div_h11:
    h11 = div_h11.get_text(strip=True)  # Extract text from the found div
else:
    h11 = ""  # Set h11 to empty string if the div is not found

# Extract paragraph 39 text from bounding box "307 1094 1571 1600"
div_p39 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 307 1094 1571 1600" in value)
if div_p39:
    p39 = div_p39.get_text(strip=True)  # Extract text from the found div
else:
    p39 = ""  # Set p39 to empty string if the div is not found

# Extract paragraph 40 text from bounding box "308 1609 1567 1797"
div_p40 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 308 1609 1567 1797" in value)
if div_p40:
    p40 = div_p40.get_text(strip=True)  # Extract text from the found div
else:
    p40 = ""  # Set p40 to empty string if the div is not found

# Extract subheading 12_0 text from bounding box "258 1876 300 1919"
div_h12_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 258 1876 300 1919" in value)
if div_h12_0:
    h12_0 = div_h12_0.get_text(strip=True)  # Extract text from the found div
else:
    h12_0 = ""  # Set h12_0 to empty string if the div is not found

# Extract heading 12 text from bounding box "315 1874 481 1926"
div_h12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 1874 481 1926" in value)
if div_h12:
    h12 = div_h12.get_text(strip=True)  # Extract text from the found div
else:
    h12 = ""  # Set h12 to empty string if the div is not found

# Extract paragraph 41 text from bounding box "308 1942 1566 2270"
div_p41 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 308 1942 1566 2270" in value)
if div_p41:
    p41 = div_p41.get_text(strip=True)  # Extract text from the found div
else:
    p41 = ""  # Set p41 to empty string if the div is not found

# Extract paragraph 42 text from bounding box "318 177 1575 683"
div_p42 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 318 177 1575 683" in value)
if div_p42:
    p42 = div_p42.get_text(strip=True)  # Extract text from the found div
else:
    p42 = ""  # Set p42 to empty string if the div is not found

# Extract paragraph 43 text from bounding box "319 681 1636 764"
div_p43 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 319 681 1636 764" in value)
if div_p43:
    p43 = div_p43.get_text(strip=True)  # Extract text from the found div
else:
    p43 = ""  # Set p43 to empty string if the div is not found

# Extract heading 13 text from bounding box "315 811 710 866"
div_h13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 811 710 866" in value)
if div_h13:
    h13 = div_h13.get_text(strip=True)  # Extract text from the found div
else:
    h13 = ""  # Set h13 to empty string if the div is not found

# Extract paragraph 44 text from bounding box "317 885 1573 1071"
div_p44 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 317 885 1573 1071" in value)
if div_p44:
    p44 = div_p44.get_text(strip=True)  # Extract text from the found div
else:
    p44 = ""  # Set p44 to empty string if the div is not found

# Extract subheading 14_0 text from bounding box "264 1157 292 1200"
div_h14_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 264 1157 292 1200" in value)
if div_h14_0:
    h14_0 = div_h14_0.get_text(strip=True)  # Extract text from the found div
else:
    h14_0 = ""  # Set h14_0 to empty string if the div is not found

# Extract heading 14 text from bounding box "317 1151 639 1208"
div_h14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 317 1151 639 1208" in value)
if div_h14:
    h14 = div_h14.get_text(strip=True)  # Extract text from the found div
else:
    h14 = ""  # Set h14 to empty string if the div is not found

# Extract paragraph 45 text from bounding box "317 1224 1570 1367"
div_p45 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 317 1224 1570 1367" in value)
if div_p45:
    p45 = div_p45.get_text(strip=True)  # Extract text from the found div
else:
    p45 = ""  # Set p45 to empty string if the div is not found


# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subtext -->
        <head>{sh1}</head>
        <!-- Heading -->
        <head>{h2}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
        <p>{p7}</p>
      </div>
      <div>
       <!-- Heading -->
        <head>{h3}</head>
        <!-- Subtext -->
        <head>{sh2}</head>
        <p>{p8}</p>
        <!-- Heading -->
        <head>{h4}</head>
        <p>{p9}</p>
        <!-- Heading -->
        <head>{h5}</head>
        <p>{p10}</p>
        <p>{p11}</p>
      </div>
      <div>
        <!-- Heading -->
        <head>{h6}</head>
        <p>{p12}</p>
        <p>{p13}</p>
        <p>{p14}</p>
        <!-- Heading -->
        <head>{h7}</head>
        <p>{p15}</p>
        <list type="number">
          <item n="1">{p16}</item>
          <item n="2">{p17}</item>
        </list>
        <p>{p18}</p>
        <p>{p19}</p>
      </div>
      <div>
        <p>{p20}</p>
        <!-- Heading -->
        <head>{h8_0} {h8}</head>
        <p>{p21} {p22} {p23} {p24} {p25} {p26} {p27} {p28} {p29}</p>
        <p>{p30}</p>
      </div>
      <div>
      <p>{p31}</p>
        <!-- Heading -->
        <head>{h9}</head>
        <p>{p32}</p>
        <p>{p33}</p>
        <!-- Heading -->
        <head>{h10}</head>
        <p>{p34}</p>
        <p>{p35}</p>
      </div>
      <div>
        <p>{p36}</p>
        <p>{p37}</p>
        <p>{p38}</p>
        <!-- Heading -->
        <head>{h11_0} {h11}</head>
        <p>{p39}</p>
        <p>{p40}</p>
        <!-- Heading -->
        <head>{h12_0} {h12}</head>
        <p>{p41}</p>
      </div>
      <div>
        <p>{p42}</p>
        <p>{p43}</p>
        <!-- Heading -->
        <head>{h13}</head>
        <p>{p44}</p>
        <!-- Heading -->
        <head>{h14_0} {h14}</head>
        <p>{p45}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_Muster_0002.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
