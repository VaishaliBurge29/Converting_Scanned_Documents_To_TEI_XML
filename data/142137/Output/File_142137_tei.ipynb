# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_142137.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "133 145 991 231"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 133 145 991 231" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "427 1255 696 1286"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 427 1255 696 1286" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b\d+,\s\w+\s\d+\b", text)  # Updated regex to match the specified format
    if match:
        date_text = match.group(0)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "129 1430 992 1469"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 1430 992 1469" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "129 1430 992 1469"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 1430 992 1469" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\. G\. [A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "143 394 980 476"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 143 394 980 476" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "340 488 783 525"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 340 488 783 525" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract heading 2 text from bounding box "386 561 734 631"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 386 561 734 631" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "468 698 654 727"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 468 698 654 727" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "189 752 933 844"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 189 752 933 844" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "228 917 894 1183"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 228 917 894 1183" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "427 1255 696 1286"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 427 1255 696 1286" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "129 1430 992 1469"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 1430 992 1469" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "465 1513 677 1552"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 465 1513 677 1552" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "130 142 992 228"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 130 142 992 228" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract heading 3 text from bounding box "129 275 456 354"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 275 456 354" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "130 364 992 426"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 130 364 992 426" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "126 438 990 501"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 126 438 990 501" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "126 505 992 597"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 126 505 992 597" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "126 603 992 668"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 126 603 992 668" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "129 669 994 740"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 669 994 740" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "129 749 496 783"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 749 496 783" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "128 790 991 857"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 128 790 991 857" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "131 862 814 896"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 131 862 814 896" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "129 901 991 970"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 901 991 970" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "129 979 631 1145"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 979 631 1145" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "122 1149 991 1218"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 122 1149 991 1218" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "128 1223 790 1395"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 128 1223 790 1395" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "128 1396 990 1467"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 128 1396 990 1467" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract heading 4 text from bounding box "360 147 860 231"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 360 147 860 231" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract heading 5 text from bounding box "504 246 714 292"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 504 246 714 292" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "177 305 1041 386"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 177 305 1041 386" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract heading 6 text from bounding box "176 436 864 512"
div_h6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 436 864 512" in value)
if div_h6:
    h6 = div_h6.get_text(strip=True)  # Extract text from the found div
else:
    h6 = ""  # Set h6 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "174 518 1044 656"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 174 518 1044 656" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract subheading 2 text from bounding box "178 682 369 718"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 178 682 369 718" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "176 728 1039 792"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 728 1039 792" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract heading 7 text from bounding box "411 823 812 865"
div_h7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 411 823 812 865" in value)
if div_h7:
    h7 = div_h7.get_text(strip=True)  # Extract text from the found div
else:
    h7 = ""  # Set h7 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "176 874 1040 980"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 874 1040 980" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract subheading 3 text from bounding box "179 1003 326 1040"
div_sh3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 179 1003 326 1040" in value)
if div_sh3:
    sh3 = div_sh3.get_text(strip=True)  # Extract text from the found div
else:
    sh3 = ""  # Set sh3 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "172 1046 1048 1299"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 172 1046 1048 1299" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "175 1313 1039 1395"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 175 1313 1039 1395" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "176 1402 738 1464"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 1402 738 1464" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "187 144 884 186"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 144 884 186" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found

# Extract paragraph 29 text from bounding box "187 186 1051 252"
div_p29 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 186 1051 252" in value)
if div_p29:
    p29 = div_p29.get_text(strip=True)  # Extract text from the found div
else:
    p29 = ""  # Set p29 to empty string if the div is not found

# Extract paragraph 30 text from bounding box "186 255 915 335"
div_p30 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 186 255 915 335" in value)
if div_p30:
    p30 = div_p30.get_text(strip=True)  # Extract text from the found div
else:
    p30 = ""  # Set p30 to empty string if the div is not found

# Extract paragraph 31 text from bounding box "187 340 1051 404"
div_p31 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 340 1051 404" in value)
if div_p31:
    p31 = div_p31.get_text(strip=True)  # Extract text from the found div
else:
    p31 = ""  # Set p31 to empty string if the div is not found

# Extract paragraph 32 text from bounding box "187 407 610 443"
div_p32 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 407 610 443" in value)
if div_p32:
    p32 = div_p32.get_text(strip=True)  # Extract text from the found div
else:
    p32 = ""  # Set p32 to empty string if the div is not found

# Extract paragraph 33 text from bounding box "187 449 1069 562"
div_p33 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 449 1069 562" in value)
if div_p33:
    p33 = div_p33.get_text(strip=True)  # Extract text from the found div
else:
    p33 = ""  # Set p33 to empty string if the div is not found

# Extract paragraph 34 text from bounding box "187 544 638 582"
div_p34 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 544 638 582" in value)
if div_p34:
    p34 = div_p34.get_text(strip=True)  # Extract text from the found div
else:
    p34 = ""  # Set p34 to empty string if the div is not found

# Extract paragraph 35 text from bounding box "186 585 1050 651"
div_p35 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 186 585 1050 651" in value)
if div_p35:
    p35 = div_p35.get_text(strip=True)  # Extract text from the found div
else:
    p35 = ""  # Set p35 to empty string if the div is not found

# Extract paragraph 36 text from bounding box "187 655 429 689"
div_p36 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 655 429 689" in value)
if div_p36:
    p36 = div_p36.get_text(strip=True)  # Extract text from the found div
else:
    p36 = ""  # Set p36 to empty string if the div is not found

# Extract heading 8 text from bounding box "440 739 801 779"
div_h8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 440 739 801 779" in value)
if div_h8:
    h8 = div_h8.get_text(strip=True)  # Extract text from the found div
else:
    h8 = ""  # Set h8 to empty string if the div is not found

# Extract paragraph 37 text from bounding box "186 787 1050 1007"
div_p37 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 186 787 1050 1007" in value)
if div_p37:
    p37 = div_p37.get_text(strip=True)  # Extract text from the found div
else:
    p37 = ""  # Set p37 to empty string if the div is not found

# Extract subheading 4 text from bounding box "187 1031 335 1067"
div_sh4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 1031 335 1067" in value)
if div_sh4:
    sh4 = div_sh4.get_text(strip=True)  # Extract text from the found div
else:
    sh4 = ""  # Set sh4 to empty string if the div is not found

# Extract paragraph 38 text from bounding box "182 1075 1067 1208"
div_p38 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 182 1075 1067 1208" in value)
if div_p38:
    p38 = div_p38.get_text(strip=True)  # Extract text from the found div
else:
    p38 = ""  # Set p38 to empty string if the div is not found

# Extract paragraph 39 text from bounding box "185 1211 1048 1319"
div_p39 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 185 1211 1048 1319" in value)
if div_p39:
    p39 = div_p39.get_text(strip=True)  # Extract text from the found div
else:
    p39 = ""  # Set p39 to empty string if the div is not found

# Extract paragraph 40 text from bounding box "184 1339 908 1471"
div_p40 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 184 1339 908 1471" in value)
if div_p40:
    p40 = div_p40.get_text(strip=True)  # Extract text from the found div
else:
    p40 = ""  # Set p40 to empty string if the div is not found

# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <!-- Document metadata -->
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subheading -->
        <head>{sh1}</head>
        <!-- Heading -->
        <head>{h2}</head>
        <!-- Paragraphs -->
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
      </div>
      <div>
        <!-- Heading -->
        <head>{h4}</head>
        <!-- Heading -->
        <head>{h5}</head>
        <!-- Paragraphs -->
        <p>{p21}</p>
        <!-- Heading -->
        <head>{h6}</head>
        <!-- Paragraphs -->
        <p>{p22}</p>
        <!-- Subheading -->
        <head>{sh2}</head>
        <!-- Paragraphs -->
        <p>{p23}</p>
        <!-- Heading -->
        <head>{h7}</head>
        <!-- Paragraphs -->
        <p>{p24}</p>
        <!-- Subheading -->
        <head>{sh3}</head>
        <!-- Paragraphs -->
        <p>{p25}</p>
        <p>{p26}</p>
        <p>{p27}</p>
      </div>
      <div>
        <!-- Paragraphs -->
        <p>{p7}</p>
        <!-- Heading -->
        <head>{h3}</head>
        <!-- Paragraphs -->
        <p>{p8}</p>
        <p>{p9}</p>
        <p>{p10}</p>
        <p>{p11}</p>
        <p>{p12}</p>
        <p>{p13}</p>
        <p>{p14}</p>
        <p>{p15}</p>
        <p>{p16}</p>
        <p>{p17}</p>
        <p>{p18}</p>
        <p>{p19}</p>
        <p>{p20}</p>
      </div>
      <div>
        <!-- Paragraphs -->
        <p>{p28}</p>
        <p>{p29}</p>
        <p>{p30}</p>
        <p>{p31}</p>
        <p>{p32}</p>
        <p>{p33}</p>
        <p>{p34}</p>
        <p>{p35}</p>
        <p>{p36}</p>
        <!-- Heading -->
        <head>{h8}</head>
        <!-- Paragraphs -->
        <p>{p37}</p>
        <!-- Subheading -->
        <head>{sh4}</head>
        <!-- Paragraphs -->
        <p>{p38}</p>
        <p>{p39}</p>
        <p>{p40}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("final_output_142137.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
