# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_142317.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "132 134 994 219"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 132 134 994 219" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "396 1227 708 1260"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 396 1227 708 1260" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b\d+.\s\w+\s\d+\b", text)  # Search for a specific date format
    if match:
        date_text = match.group(0)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "124 1427 986 1465"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 124 1427 986 1465" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "124 1427 986 1465"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 124 1427 986 1465" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\.G\.[A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "225 385 897 461"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 225 385 897 461" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "432 488 691 521"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 432 488 691 521" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract heading 2 text from bounding box "119 549 734 640"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 119 549 734 640" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "469 714 653 742"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 469 714 653 742" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "187 767 933 860"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 187 767 933 860" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "222 969 899 1121"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 222 969 899 1121" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "396 1227 708 1260"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 396 1227 708 1260" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "124 1427 986 1465"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 124 1427 986 1465" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "459 1510 647 1550"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 459 1510 647 1550" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "159 136 1023 278"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 159 136 1023 278" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract heading 3 text from bounding box "160 346 635 390"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 160 346 635 390" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "158 398 872 553"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 158 398 872 553" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract heading 4 text from bounding box "158 599 1018 671"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 158 599 1018 671" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "153 679 1023 904"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 679 1023 904" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "153 1030 767 1181"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1030 767 1181" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "152 1183 1014 1244"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 1183 1014 1244" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "153 1248 800 1286"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1248 800 1286" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "152 1286 1013 1350"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 1286 1013 1350" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "152 1351 662 1425"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 1351 662 1425" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "151 1426 563 1467"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 1426 563 1467" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "620 134 1334 366"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 620 134 1334 366" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract subheading 2 text from bounding box "621 394 781 429"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 621 394 781 429" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "621 439 1090 477"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 621 439 1090 477" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "622 478 940 515"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 622 478 940 515" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract heading 5 text from bounding box "454 130 651 164"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 454 130 651 164" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "120 171 983 237"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 120 171 983 237" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract heading 6 text from bounding box "457 275 651 312"
div_h6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 457 275 651 312" in value)
if div_h6:
    h6 = div_h6.get_text(strip=True)  # Extract text from the found div
else:
    h6 = ""  # Set h6 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "121 316 985 411"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 121 316 985 411" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "81 490 988 634"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 81 490 988 634" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "125 635 989 702"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 125 635 989 702" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found


# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subheading -->
        <head>{sh1}</head>
        <!-- Heading -->
        <head>{h2}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
      </div>
      <div>
        <p>{p7}</p>
        <!-- Heading -->
        <head>{h3}</head>
        <p>{p8}</p>
        <!-- Heading -->
        <head>{h4}</head>
        <p>{p9}</p>
        <p>{p10}</p>
        <p>{p11}</p>
        <p>{p12}</p>
        <p>{p13}</p>
        <p>{p14}</p>
        <p>{p15}</p>
      </div>
      <div>
        <p>{p16}</p>
        <!-- Sub-heading -->
        <head>{sh2}</head>
        <p>{p17}</p>
        <p>{p18}</p>
      </div>
      <div>
        <!-- Heading -->
        <head>{h5}</head>
        <p>{p19}</p>
        <!-- Heading -->
        <head>{h6}</head>
        <p>{p20}</p>
        <p>{p21}</p>
        <p>{p22}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_142317.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
