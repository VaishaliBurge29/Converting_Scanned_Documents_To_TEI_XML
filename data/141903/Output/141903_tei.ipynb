# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_141903.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "956 281 2244 593"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 956 281 2244 593" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "1333 1966 1861 2014"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1333 1966 1861 2014" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"(\d+,\s\w+\s\d+)", text)  # Search for a specific date format
    if match:
        date_text = match.group(1)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "1004 2163 2184 2214"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1004 2163 2184 2214" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "1004 2163 2184 2214"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1004 2163 2184 2214" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\. [A-Z]\. [A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract paragraph 1 text from bounding box "1264 664 1938 725"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1264 664 1938 725" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract heading 1 text from bounding box "1224 784 1971 973"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1224 784 1971 973" in value)
if div_h1:
    h1 = div_h1.find("span", class_="ocr_line").get_text(strip=True)  # Extract text from the found div
    sh1 = div_h1.find_all("span", class_="ocr_line")[1].get_text(strip=True)
else:
    h1 = ""  # Set h1 to empty string if the div is not found
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "1466 1071 1724 1116"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1466 1071 1724 1116" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "1040 1147 2157 1259"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1040 1147 2157 1259" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "1388 1305 1798 1713"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1388 1305 1798 1713" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "1064 1729 2098 1850"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1064 1729 2098 1850" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "1333 1966 1861 2014"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1333 1966 1861 2014" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "1004 2163 2184 2214"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1004 2163 2184 2214" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "2013 2249 2287 2329"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 2013 2249 2287 2329" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract heading 2 text from bounding box "752 267 1842 495"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 752 267 1842 495" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract subheading 2 text from bounding box "963 554 1641 754"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 963 554 1641 754" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "391 776 2209 984"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 391 776 2209 984" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract heading 3 text from bounding box "798 1131 1794 1223"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 798 1131 1794 1223" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract heading 4 text from bounding box "390 1250 685 1313"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 390 1250 685 1313" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract heading 5 text from bounding box "387 1609 666 1677"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 387 1609 666 1677" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "769 1247 2210 1440"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 769 1247 2210 1440" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "770 1450 2212 1750"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 770 1450 2212 1750" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "390 1776 2210 1844"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 390 1776 2210 1844" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "827 1839 2211 1968"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 827 1839 2211 1968" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract heading 7 text from bounding box "916 2101 1682 2181"
div_h7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 916 2101 1682 2181" in value)
if div_h7:
    h7 = div_h7.get_text(strip=True)  # Extract text from the found div
else:
    h7 = ""  # Set h7 to empty string if the div is not found

# Extract heading 8 text from bounding box "392 2215 688 2279"
div_h8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 392 2215 688 2279" in value)
if div_h8:
    h8 = div_h8.get_text(strip=True)  # Extract text from the found div
else:
    h8 = ""  # Set h8 to empty string if the div is not found

# Extract heading 9 text from bounding box "385 2711 665 2777"
div_h9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 385 2711 665 2777" in value)
if div_h9:
    h9 = div_h9.get_text(strip=True)  # Extract text from the found div
else:
    h9 = ""  # Set h9 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "771 2214 2214 2333"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 771 2214 2214 2333" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "772 2364 2215 2492"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 772 2364 2215 2492" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "852 2500 2217 2689"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 852 2500 2217 2689" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "387 2802 2218 2874"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 387 2802 2218 2874" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "894 2866 1619 2933"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 894 2866 1619 2933" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "770 2954 2213 3148"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 770 2954 2213 3148" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "661 272 2101 403"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 661 272 2101 403" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "661 436 2103 561"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 661 436 2103 561" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "663 602 2102 738"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 663 602 2102 738" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "665 767 2106 1023"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 665 767 2106 1023" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "665 1058 1307 1123"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 665 1058 1307 1123" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "665 1157 2108 1292"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 665 1157 2108 1292" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract heading 10 text from bounding box "841 1426 1543 1507"
div_h10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 841 1426 1543 1507" in value)
if div_h10:
    h10 = div_h10.get_text(strip=True)  # Extract text from the found div
else:
    h10 = ""  # Set h10 to empty string if the div is not found

# Extract heading 11 text from bounding box "287 1549 583 1613"
div_h11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 287 1549 583 1613" in value)
if div_h11:
    h11 = div_h11.get_text(strip=True)  # Extract text from the found div
else:
    h11 = ""  # Set h11 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "668 1548 1301 1614"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 668 1548 1301 1614" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "667 1651 2109 1780"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 667 1651 2109 1780" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found

# Extract paragraph 29 text from bounding box "748 1787 2113 2108"
div_p29 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 748 1787 2113 2108" in value)
if div_p29:
    p29 = div_p29.get_text(strip=True)  # Extract text from the found div
else:
    p29 = ""  # Set p29 to empty string if the div is not found

# Extract paragraph 30 text from bounding box "668 2141 2110 2270"
div_p30 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 668 2141 2110 2270" in value)
if div_p30:
    p30 = div_p30.get_text(strip=True)  # Extract text from the found div
else:
    p30 = ""  # Set p30 to empty string if the div is not found

# Extract paragraph 31 text from bounding box "754 2282 2117 2471"
div_p31 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 754 2282 2117 2471" in value)
if div_p31:
    p31 = div_p31.get_text(strip=True)  # Extract text from the found div
else:
    p31 = ""  # Set p31 to empty string if the div is not found

# Extract paragraph 32 text from bounding box "672 2504 2056 2576"
div_p32 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 672 2504 2056 2576" in value)
if div_p32:
    p32 = div_p32.get_text(strip=True)  # Extract text from the found div
else:
    p32 = ""  # Set p32 to empty string if the div is not found

# Extract paragraph 33 text from bounding box "751 2579 2115 2832"
div_p33 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 751 2579 2115 2832" in value)
if div_p33:
    p33 = div_p33.get_text(strip=True)  # Extract text from the found div
else:
    p33 = ""  # Set p33 to empty string if the div is not found

# Extract heading 12 text from bounding box "290 2875 570 2941"
div_h12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 290 2875 570 2941" in value)
if div_h12:
    h12 = div_h12.get_text(strip=True)  # Extract text from the found div
else:
    h12 = ""  # Set h12 to empty string if the div is not found

# Extract paragraph 34 text from bounding box "294 2987 1492 3059"
div_p34 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 294 2987 1492 3059" in value)
if div_p34:
    p34 = div_p34.get_text(strip=True)  # Extract text from the found div
else:
    p34 = ""  # Set p34 to empty string if the div is not found

# Extract paragraph 35 text from bounding box "675 3084 1162 3152"
div_p35 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 675 3084 1162 3152" in value)
if div_p35:
    p35 = div_p35.get_text(strip=True)  # Extract text from the found div
else:
    p35 = ""  # Set p35 to empty string if the div is not found


# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Subtext -->
        <p>{p1}</p>
        <head>{h1}</head>
        <!-- Subtext -->
        <head>{sh1}</head>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
        <p>{p7}</p>
        <p>{p8}</p>
      </div>
      <div>
        <head>{h2}</head>
        <!-- Subtext -->
        <head>{sh2}</head>
        <p>{p9}</p>
        <!-- Heading -->
        <head>{h3}</head>
        <!--Sub-heading -->
        <head>{h4}</head>
        <p>{p10}</p>
        <head>{h5}</head>
        <p>{p12}</p>
        <p>{p13} {p14}</p>
      </div>
      <div>
        <head>{h7}</head>
        <!--Sub-heading -->
        <head>{h8}</head>
        <p>{p15} {p16} {p17}</p>
        <head>{h9}</head>
        <p>{p18} {p19} {p20}</p>
      </div>
      <div>
        <p>{p21} {p22} {p23} {p24} {p25} {p26}</p>
        <head>{h10}</head>
        <!--Sub-heading -->
        <head>{h11}</head>
        <p>{p27} {p28} {p29} {p30} {p31} {p32} {p33}</p>
        <head>{h12}</head>
        <p>{p34} {p35}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_1419031.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
