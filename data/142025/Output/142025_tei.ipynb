# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_142025.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "226 183 1519 330"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 226 183 1519 330" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "606 1959 1135 2011"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 606 1959 1135 2011" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"(\d+\.\s\w+\s\d+)", text)  # Search for a specific date format
    if match:
        date_text = match.group(1)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "225 2164 1515 2221"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 225 2164 1515 2221" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "225 2164 1515 2221"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 225 2164 1515 2221" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\.G\. [A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "422 546 1322 661"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 422 546 1322 661" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "665 707 1076 764"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 665 707 1076 764" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract heading 2 text from bounding box "547 820 1197 930"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 547 820 1197 930" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "742 1052 1001 1098"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 742 1052 1001 1098" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "333 1129 1410 1183"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 333 1129 1410 1183" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "719 1223 1026 1327"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 719 1223 1026 1327" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "669 1344 1076 1396"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 669 1344 1076 1396" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "383 1528 1358 1845"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 383 1528 1358 1845" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "606 1959 1135 2011"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 606 1959 1135 2011" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "225 2164 1515 2221"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 225 2164 1515 2221" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "1283 2255 1560 2338"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1283 2255 1560 2338" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract heading 3 text from bounding box "305 231 2129 358"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 305 231 2129 358" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract subheading 2 text from bounding box "828 386 1598 570"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 828 386 1598 570" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "306 597 2129 732"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 306 597 2129 732" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract heading 4 text from bounding box "306 934 1385 1027"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 306 934 1385 1027" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "639 1054 2131 1471"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 639 1054 2131 1471" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract heading 5 text from bounding box "303 1590 2129 1777"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 303 1590 2129 1777" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "635 1775 2126 2877"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 635 1775 2126 2877" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract subheading 3 text from bounding box "298 2908 599 2975"
div_sh3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 298 2908 599 2975" in value)
if div_sh3:
    sh3 = div_sh3.get_text(strip=True)  # Extract text from the found div
else:
    sh3 = ""  # Set sh3 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "635 2911 2065 3124"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 635 2911 2065 3124" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "63 271 2091 578"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 63 271 2091 578" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract heading 6 text from bounding box "66 712 920 810"
div_h6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 66 712 920 810" in value)
if div_h6:
    h6 = div_h6.get_text(strip=True)  # Extract text from the found div
else:
    h6 = ""  # Set h6 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "63 830 2084 1270"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 63 830 2084 1270" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "60 1298 2085 1669"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 60 1298 2085 1669" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "510 1724 2083 1872"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 510 1724 2083 1872" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "622 1885 2082 2032"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 622 1885 2082 2032" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "105 2051 2081 2318"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 105 2051 2081 2318" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "60 2305 2082 2491"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 60 2305 2082 2491" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "539 2456 2077 2703"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 539 2456 2077 2703" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "507 2716 2081 2864"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 507 2716 2081 2864" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "53 2916 2080 3351"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 53 2916 2080 3351" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "59 3378 2079 3463"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 59 3378 2079 3463" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "479 235 2231 427"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 479 235 2231 427" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract heading 7 text from bounding box "477 553 1286 625"
div_h7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 477 553 1286 625" in value)
if div_h7:
    h7 = div_h7.get_text(strip=True)  # Extract text from the found div
else:
    h7 = ""  # Set h7 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "475 648 2232 910"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 475 648 2232 910" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "475 925 2231 1688"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 475 925 2231 1688" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "473 1707 2227 1965"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 473 1707 2227 1965" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract heading 8.0 text from bounding box "398 2105 454 2161"
div_h8_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 398 2105 454 2161" in value)
if div_h8_0:
    h8_0 = div_h8_0.get_text(strip=True)  # Extract text from the found div
else:
    h8_0 = ""  # Set h8_0 to empty string if the div is not found

# Extract heading 8 text from bounding box "471 2100 2225 2241"
div_h8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 471 2100 2225 2241" in value)
if div_h8:
    h8 = div_h8.get_text(strip=True)  # Extract text from the found div
else:
    h8 = ""  # Set h8 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "468 2271 2221 2586"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 468 2271 2221 2586" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found

# Extract paragraph 29 text from bounding box "467 2605 2221 3111"
div_p29 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 467 2605 2221 3111" in value)
if div_p29:
    p29 = div_p29.get_text(strip=True)  # Extract text from the found div
else:
    p29 = ""  # Set p29 to empty string if the div is not found

# Extract paragraph 30 text from bounding box "380 256 2144 387"
div_p30 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 380 256 2144 387" in value)
if div_p30:
    p30 = div_p30.get_text(strip=True)  # Extract text from the found div
else:
    p30 = ""  # Set p30 to empty string if the div is not found

# Extract paragraph 31 text from bounding box "377 401 2138 800"
div_p31 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 377 401 2138 800" in value)
if div_p31:
    p31 = div_p31.get_text(strip=True)  # Extract text from the found div
else:
    p31 = ""  # Set p31 to empty string if the div is not found

# Extract paragraph 32 text from bounding box "350 786 2135 865"
div_p32 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 350 786 2135 865" in value)
if div_p32:
    p32 = div_p32.get_text(strip=True)  # Extract text from the found div
else:
    p32 = ""  # Set p32 to empty string if the div is not found

# Extract paragraph 33 text from bounding box "377 868 2134 1132"
div_p33 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 377 868 2134 1132" in value)
if div_p33:
    p33 = div_p33.get_text(strip=True)  # Extract text from the found div
else:
    p33 = ""  # Set p33 to empty string if the div is not found

# Extract heading 9.0 text from bounding box "301 1214 371 1301"
div_h9_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 301 1214 371 1301" in value)
if div_h9_0:
    h9_0 = div_h9_0.get_text(strip=True)  # Extract text from the found div
else:
    h9_0 = ""  # Set h9_0 to empty string if the div is not found

# Extract heading 9 text from bounding box "375 1243 1253 1315"
div_h9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 375 1243 1253 1315" in value)
if div_h9:
    h9 = div_h9.get_text(strip=True)  # Extract text from the found div
else:
    h9 = ""  # Set h9 to empty string if the div is not found

# Extract paragraph 34 text from bounding box "372 1340 2132 1856"
div_p34 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 372 1340 2132 1856" in value)
if div_p34:
    p34 = div_p34.get_text(strip=True)  # Extract text from the found div
else:
    p34 = ""  # Set p34 to empty string if the div is not found

# Extract paragraph 35 text from bounding box "372 1870 2128 2117"
div_p35 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 372 1870 2128 2117" in value)
if div_p35:
    p35 = div_p35.get_text(strip=True)  # Extract text from the found div
else:
    p35 = ""  # Set p35 to empty string if the div is not found

# Extract heading 10.0 text from bounding box "297 2223 355 2281"
div_h10_0 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 297 2223 355 2281" in value)
if div_h10_0:
    h10_0 = div_h10_0.get_text(strip=True)  # Extract text from the found div
else:
    h10_0 = ""  # Set h10_0 to empty string if the div is not found

# Extract heading 10 text from bounding box "376 2214 602 2292"
div_h10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 376 2214 602 2292" in value)
if div_h10:
    h10 = div_h10.get_text(strip=True)  # Extract text from the found div
else:
    h10 = ""  # Set h10 to empty string if the div is not found

# Extract paragraph 36 text from bounding box "354 2323 2123 3147"
div_p36 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 354 2323 2123 3147" in value)
if div_p36:
    p36 = div_p36.get_text(strip=True)  # Extract text from the found div
else:
    p36 = ""  # Set p36 to empty string if the div is not found

# Extract paragraph 37 text from bounding box "1043 178 2289 456"
div_p37 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1043 178 2289 456" in value)
if div_p37:
    p37 = div_p37.get_text(strip=True)  # Extract text from the found div
else:
    p37 = ""  # Set p37 to empty string if the div is not found

# Extract heading 11 text from bounding box "998 530 1436 587"
div_h11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 998 530 1436 587" in value)
if div_h11:
    h11 = div_h11.get_text(strip=True)  # Extract text from the found div
else:
    h11 = ""  # Set h11 to empty string if the div is not found

# Extract paragraph 38 text from bounding box "1047 602 2292 789"
div_p38 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1047 602 2292 789" in value)
if div_p38:
    p38 = div_p38.get_text(strip=True)  # Extract text from the found div
else:
    p38 = ""  # Set p38 to empty string if the div is not found

# Extract heading 12 text from bounding box "1000 862 1370 917"
div_h12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1000 862 1370 917" in value)
if div_h12:
    h12 = div_h12.get_text(strip=True)  # Extract text from the found div
else:
    h12 = ""  # Set h12 to empty string if the div is not found

# Extract paragraph 39 text from bounding box "1053 932 2293 1074"
div_p39 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1053 932 2293 1074" in value)
if div_p39:
    p39 = div_p39.get_text(strip=True)  # Extract text from the found div
else:
    p39 = ""  # Set p39 to empty string if the div is not found


# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subtext -->
        <head>{sh1}</head>
         <!-- Heading -->
        <head>{h2}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
        <p>{p7}</p>
        <p>{p8}</p>
      </div>
      <div>
       <!-- Heading -->
        <head>{h3}</head>
        <!-- Subtext -->
        <head>{sh2}</head>
        <p>{p9}</p>
        <!-- Heading -->
        <head>{h4}</head>
        <p>{p10}</p>
        <!-- Heading -->
        <head>{h5}</head>
        <p>{p11}</p>
        <!-- Sub-heading -->
        <head>{sh3}</head>
        <p>{p12}</p>
      </div>
      <div>
          <p>{p13}</p>
        <!-- Heading -->
        <head>{h6}</head>
        <p>{p14} {p15}</p>
        <p>{p16}</p>
        <p>{p17}</p>
        <p>{p18}</p>
        <p>{p19}</p>
        <p>{p20}</p>
        <p>{p21}</p>
        <p>{p22} {p23}</p>
      </div>
      <div>
        <p>{p24}</p>
        <!-- Heading -->
        <head>{h7}</head>
        <p>{p25} {p26} {p27}</p>
         <!-- Heading -->
        <head>{h8_0} {h8}</head>
        <p>{p28} {p29}</p>
      </div>
      <div>
      <p>{p30} {p31} {p32} {p33}</p>
      <!-- Heading -->
      <head>{h9_0} {h9}</head>
      <p>{p34} {p35}</p>
      <!-- Heading -->
      <head>{h10_0} {h10}</head>
      <p>{p36}</p>
    </div>
    <div>
      <p>{p37}</p>
      <!-- Heading -->
      <head>{h11}</head>
      <p>{p38}</p>
      <!-- Heading -->
      <head>{h12}</head>
      <p>{p39}</p>
    </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_142025.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
