# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_feinpolier.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "68 78 474 189"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 68 78 474 189" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract heading 1 text from bounding box "66 251 472 322"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 66 251 472 322" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "224 355 315 382"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 224 355 315 382" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "77 378 460 423"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 77 378 460 423" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "100 427 441 552"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 100 427 441 552" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract heading 2 text from bounding box "58 64 500 102"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 58 64 500 102" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "180 96 377 177"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 180 96 377 177" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract heading 3 text from bounding box "62 230 301 260"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 62 230 301 260" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "141 261 499 307"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 141 261 499 307" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "62 332 479 629"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 62 332 479 629" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "322 66 775 469"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 322 66 775 469" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "325 488 536 533"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 325 488 536 533" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "84 65 501 140"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 84 65 501 140" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "73 154 502 303"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 73 154 502 303" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "74 316 506 515"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 74 316 506 515" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "84 514 134 535"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 84 514 134 535" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "322 62 761 120"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 322 62 761 120" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "343 115 762 166"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 343 115 762 166" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract heading 4 text from bounding box "324 178 478 207"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 324 178 478 207" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "344 206 667 400"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 344 206 667 400" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "320 409 764 589"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 320 409 764 589" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
      </titleStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
      </div>
      <div>
        <!-- Heading -->
        <head>{h2}</head>
        <p>{p4}</p>
        <!-- Heading -->
        <head>{h3}</head>
        <p>{p5}</p>
        <p>{p6}</p>
      </div>
      <div>
        <p>{p7}</p>
        <p>{p8}</p>
      </div>
      <div>
        <p>{p9}</p>
        <p>{p10}</p>
        <p>{p11}</p>
        <p>{p12}</p>
      </div>
      <div>
        <p>{p13}</p>
        <p>{p14}</p>
        <!-- Heading -->
        <head>{h4}</head>
        <p>{p15}</p>
        <p>{p16}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("final_output_feinpolier.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)   # Write the TEI XML document content to the file
