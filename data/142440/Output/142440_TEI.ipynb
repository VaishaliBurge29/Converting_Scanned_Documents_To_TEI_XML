# %% [markdown]
# HOCR TO TEI XML
#
# This code identifies the title , Date , organisation name and publishing place by using logic with the help of regular expressions.

# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_142440.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract the title text from bounding box "bbox 631 110 1493 212"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 631 110 1493 212" in value)

if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)   # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract the date text from bounding box "bbox 153 1361 1012 1401"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1361 1012 1401" in value)

# Extract text from the second div with the specified format (\d+,\s\w+\s\d+)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"(\d+,\s\w+\s\d+)", text)  # Search for a specific date format
    if match:
        date_text = match.group(1)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract the place names from bounding box "bbox 153 1361 1012 1401"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1361 1012 1401" in value)

# Extract text from the third div with the specified format (\b[A-Z][a-z]+\b)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True) # Extract text from the found div
    match = re.search(r'\bLeipzig\b', text)  # Search for specific place names
    if match:
        place_text = match.group(0)  # Extract the matched place text
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract the organization name from bounding box "bbox 153 1361 1012 1401"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1361 1012 1401" in value)

# Extract text from the third div with the specified format for orgName
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\.[A-Z]\. [A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Find the div with class "ocr_carea" and p1 attribute containing "bbox 152 147 1015 207"
div_p1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 147 1015 207" in value)

# Extract text from the first div
if div_p1_tag:
    p1_text = div_p1_tag.get_text(strip=True)    # Extract text from the found div
else:
    p1_text = ""  # Set p1_text to empty string if the div is not found

# Find the div with class "ocr_carea" and head1 attribute containing "bbox 152 285 653 329"
div_h1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 285 653 329" in value)

# Extract text from the first div
if div_h1_tag:
    h1_text = div_h1_tag.get_text(strip=True)  # Extract text from the found div
else:
    h1_text = ""  # Set h1_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p2 attribute containing "bbox 148 319 1014 438"
div_p2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 148 319 1014 438" in value)

# Extract text from the first div
if div_p2_tag:
    p2_text = div_p2_tag.get_text(strip=True)  # Extract text from the found div
else:
    p2_text = ""  # Set p2_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 153 443 1013 507"
div_p3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 443 1013 507" in value)

# Extract text from the first div
if div_p3_tag:
    p3_text = div_p3_tag.get_text(strip=True)  # Extract text from the found div
else:
    p3_text = ""  # Set p3_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p4 attribute containing "bbox 153 507 1014 546"
div_p4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 507 1014 546" in value)

# Extract text from the first div
if div_p4_tag:
    p4_text = div_p4_tag.get_text(strip=True)  # Extract text from the found div
else:
    p4_text = ""  # Set p4_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p5 attribute containing "bbox 151 587 1018 776"
div_p5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 587 1018 776" in value)

# Extract text from the first div
if div_p5_tag:
    p5_text = div_p5_tag.get_text(strip=True)  # Extract text from the found div
else:
    p5_text = ""  # Set p5_text to empty string if the div is not found

# Find the div with class "ocr_carea" and head2 attribute containing "bbox 152 798 313 834"
div_h2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 798 313 834" in value)

# Extract text from the first div
if div_h2_tag:
    h2_text = div_h2_tag.get_text(strip=True)  # Extract text from the found div
else:
    h2_text = ""  # Set h2_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p6 attribute containing "bbox 154 835 1015 967"
div_p6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 154 835 1015 967" in value)

# Extract text from the first div
if div_p6_tag:
    p6_text = div_p6_tag.get_text(strip=True)  # Extract text from the found div
else:
    p6_text = ""  # Set p6_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p7 attribute containing "bbox 153 968 1014 1032"
div_p7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 968 1014 1032" in value)

# Extract text from the first div
if div_p7_tag:
    p7_text = div_p7_tag.get_text(strip=True)  # Extract text from the found div
else:
    p7_text = ""  # Set p7_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p8 attribute containing "bbox 154 1033 939 1072"
div_p8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 154 1033 939 1072" in value)

# Extract text from the first div
if div_p8_tag:
    p8_text = div_p8_tag.get_text(strip=True)  # Extract text from the found div
else:
    p8_text = ""  # Set p8_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p9 attribute containing "bbox 154 1071 1014 1128"
div_p9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 154 1071 1014 1128" in value)

# Extract text from the first div
if div_p9_tag:
    p9_text = div_p9_tag.get_text(strip=True)  # Extract text from the found div
else:
    p9_text = ""  # Set p9_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p10 attribute containing "bbox 149 1136 1012 1316"
div_p10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 149 1136 1012 1316" in value)

# Extract text from the first div
if div_p10_tag:
    p10_text = div_p10_tag.get_text(strip=True)  # Extract text from the found div
else:
    p10_text = ""  # Set p10_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p11 attribute containing "bbox 153 1361 1012 1401"
div_p11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 1361 1012 1401" in value)

# Extract text from the first div
if div_p11_tag:
    p11_text = div_p11_tag.get_text(strip=True)  # Extract text from the found div
else:
    p11_text = ""  # Set p11_text to empty string if the div is not found

# Define a list of target IDs
target_ids = ["bbox 655 353 1466 432", "bbox 815 461 1301 507", "bbox 844 540 1272 615"]

# Initialize a variable to store the extracted text
h3_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        h3_text += div.get_text(strip=True) + "\n"
# Define a list of target IDs
target_ids = ["bbox 700 684 1414 774", "bbox 949 797 1157 872", "bbox 917 877 1191 916"]

# Initialize a variable to store the extracted text
p12_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p12_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and p13 attribute containing "bbox 727 989 1379 1258"
div_p13_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 727 989 1379 1258" in value)

# Extract text from the first div
if div_p13_tag:
    p13_text = div_p13_tag.get_text(strip=True) # Extract text from the found div
else:
    p13_text = ""  # Set p13_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p14 attribute containing "bbox 692 1321 1225 1364"
div_p14_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 692 1321 1225 1364" in value)

# Extract text from the first div
if div_p14_tag:
    p14_text = div_p14_tag.get_text(strip=True)  # Extract text from the found div
else:
    p14_text = ""  # Set p14_text to empty string if the div is not found

# Find the div with class "ocr_carea" and p15 attribute containing "bbox 317 1289 444 2155"
div_p15_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 317 1289 444 2155" in value)

# Extract text from the first div
if div_p15_tag:
    p15_text = div_p15_tag.get_text(strip=True)  # Extract text from the found div
else:
    p15_text = ""  # Set p15_text to empty string if the div is not found

# Find the div with class "ocr_carea" and head4 attribute containing "bbox 540 1484 585 1958"
div_h4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 540 1484 585 1958" in value)

# Extract text from the first div
if div_h4_tag:
    h4_text = div_h4_tag.get_text(strip=True)  # Extract text from the found div
else:
    h4_text = ""  # Set h4_text to empty string if the div is not found

# Find the div with class "ocr_carea" and l1 attribute containing "bbox 601 1289 673 2152"
div_l1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 601 1289 673 2152" in value)

# Extract text from the first div
if div_l1_tag:
    l1_text = div_l1_tag.get_text(strip=True)  # Extract text from the found div
else:
    l1_text = ""  # Set l1_text to empty string if the div is not found

# Find the div with class "ocr_carea" and l2 attribute containing "bbox 677 1290 747 2152"
div_l2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 677 1290 747 2152" in value)

# Extract text from the first div
if div_l2_tag:
    l2_text = div_l2_tag.get_text(strip=True)  # Extract text from the found div
else:
    l2_text = ""  # Set l2_text to empty string if the div is not found

# Find the div with class "ocr_carea" and head5 attribute containing "bbox 808 1539 854 1902"
div_h5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 808 1539 854 1902" in value)

# Extract text from the first div
if div_h5_tag:
    h5_text = div_h5_tag.get_text(strip=True)  # Extract text from the found div
else:
    h5_text = ""  # Set h5_text to empty string if the div is not found

# Define a list of target IDs
target_ids = ["bbox 869 1288 968 2151", "bbox 964 1286 1034 1933", "bbox 1047 1397 1120 1970","bbox 1130 1287 1201 1971","bbox 1195 1286 1295 1937","bbox 1305 1623 1381 1971"]

# Initialize a variable to store the extracted text
l3_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        l3_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and l4 attribute containing "bbox 1408 1657 1481 2151"
div_l4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1408 1657 1481 2151" in value)

# Extract text from the first div
if div_l4_tag:
    l4_text = div_l4_tag.get_text(strip=True)  # Extract text from the found div
else:
    l4_text = ""  # Set l4_text to empty string if the div is not found

# Find the div with class "ocr_carea" and l5 attribute containing "bbox 107 166 212 852"
div_l5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 107 166 212 852" in value)

# Extract text from the first div
if div_l5_tag:
    l5_text = div_l5_tag.get_text(strip=True)  # Extract text from the found div
else:
    l5_text = ""  # Set l5_text to empty string if the div is not found

# Find the div with class "ocr_carea" and head6 attribute containing "bbox 233 489 273 1031"
div_h6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 233 489 273 1031" in value)

# Extract text from the first div
if div_h6_tag:
    h6_text = div_h6_tag.get_text(strip=True)  # Extract text from the found div
else:
    h6_text = ""  # Set h5_text to empty string if the div is not found

# Define a list of target IDs
target_ids = ["bbox 285 163 414 851", "bbox 427 323 465 851", "bbox 474 165 605 851","bbox 616 167 689 852","bbox 697 230 736 852","bbox 747 166 846 852","bbox 857 167 899 851","bbox 908 167 978 851","bbox 988 167 1034 850","bbox 1039 168 1109 851","bbox 1121 165 1186 850","bbox 1201 470 1274 849","bbox 1281 166 1351 848","bbox 1359 166 1429 851","bbox 1438 482 1477 849","bbox 840 107 1381 143","bbox 840 153 1521 221"]

# Initialize a variable to store the extracted text
p16_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p16_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and head7 attribute containing "bbox 920 274 1258 319"
div_h7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 920 274 1258 319" in value)

# Extract text from the first div
if div_h7_tag:
    h7_text = div_h7_tag.get_text(strip=True)  # Extract text from the found div
else:
    h7_text = ""  # Set h7_text to empty string if the div is not found

# Define a list of target IDs
target_ids = ["bbox 659 339 1522 652","bbox 871 647 1521 712"]

# Initialize a variable to store the extracted text
l6_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        l6_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and l7 attribute containing "bbox 657 732 1218 772"
div_l7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 657 732 1218 772" in value)

# Extract text from the first div
if div_l7_tag:
    l7_text = div_l7_tag.get_text(strip=True)  # Extract text from the found div
else:
    l7_text = ""  # Set l5_text to empty string if the div is not found

# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <persName></persName>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
    <p>{p1_text} </p>
      <!-- Subheading -->
      <div type="subheading">
        <head>{h1_text}</head>
        <!-- Paragraph -->
        <p>{p2_text}</p>
        <p>{p3_text}</p>
        <p>{p4_text}</p>
        <p>{p5_text}</p>
      </div>
      <div type="subheading">
        <head>{h2_text}</head>
        <!-- Paragraph -->
        <p>{p6_text}</p>
        <p>{p7_text}</p>
        <p>{p8_text}</p>
        <p>{p9_text}</p>
        <p>{p10_text}</p>
        <p>{p11_text}</p>
      </div>
      <div type="subheading">
      <head>{h3_text}</head>
      <p>{p12_text}</p>
      <p>{p13_text}</p>
      <p>{p14_text}</p>
      </div>
      <div>
      <p>{p15_text}</p>
      </div>
      <div type="subheading">
      <head>{h4_text}</head>
      <list type="number">
          <item n="1">{l1_text}</item>
          <item n="2">{l2_text}</item>
      </list>
     </div>
     <div type ="subheading">
     <head>{h5_text}</head>
     <list type="number">
          <item n="1">{l3_text}</item>
          <item n="2">{l4_text}</item>
          <item n="3">{l5_text}</item>
      </list>
      <head>{h6_text}</head>
      <p>{p16_text}</p>
      <head>{h7_text}</head>
      <list type="number">
          <item n="1">{l6_text}</item>
          <item n="2">{l7_text}</item>
      </list>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("output_142440.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
