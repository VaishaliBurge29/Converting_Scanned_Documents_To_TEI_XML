# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_142640.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract title text from bounding box "203 205 1491 351"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 203 205 1491 351" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract date text from bounding box "644 2013 1064 2059"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 644 2013 1064 2059" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"(\d+\.\s\w+\s\d+)", text)  # Search for a specific date format
    if match:
        date_text = match.group(1)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract place names from bounding box "209 2190 1501 2245"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 209 2190 1501 2245" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract organization name from bounding box "209 2190 1501 2245"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 209 2190 1501 2245" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\. [A-Z]\. [A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "243 569 1457 677"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 243 569 1457 677" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "476 730 1201 948"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 476 730 1201 948" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "307 1045 1402 1185"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 307 1045 1402 1185" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "700 1222 1005 1326"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 700 1222 1005 1326" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "646 1347 1057 1399"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 646 1347 1057 1399" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "329 1517 1378 1908"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 329 1517 1378 1908" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "644 2013 1064 2059"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 644 2013 1064 2059" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "209 2190 1501 2245"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 209 2190 1501 2245" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "1293 2292 1521 2331"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1293 2292 1521 2331" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract subheading 2 text from bounding box "194 185 1003 238"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 194 185 1003 238" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "462 266 1491 414"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 462 266 1491 414" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "463 437 1491 535"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 463 437 1491 535" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "465 563 1490 659"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 465 563 1490 659" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "465 659 1491 847"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 465 659 1491 847" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "465 877 996 928"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 465 877 996 928" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "466 957 1493 1098"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 466 957 1493 1098" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "469 1129 1392 1179"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 469 1129 1392 1179" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "470 1208 1494 1306"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 470 1208 1494 1306" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "469 1334 1495 1474"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 469 1334 1495 1474" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "470 1504 1494 1636"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 470 1504 1494 1636" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "471 1663 1496 1760"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 471 1663 1496 1760" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "470 1787 1496 1841"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 470 1787 1496 1841" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "472 1866 1163 1919"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 472 1866 1163 1919" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "528 1928 1496 2024"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 528 1928 1496 2024" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "472 2054 1497 2108"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 472 2054 1497 2108" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract heading 2 text from bounding box "661 195 1162 256"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 661 195 1162 256" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "265 291 1560 390"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 265 291 1560 390" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "593 401 1562 542"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 593 401 1562 542" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "536 572 1115 624"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 536 572 1115 624" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "594 631 1564 864"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 594 631 1564 864" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "539 893 1563 1230"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 539 893 1563 1230" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "271 1260 1417 1393"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 271 1260 1417 1393" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found


# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subtext -->
        <head>{sh1}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
        <p>{p7}</p>
      </div>
      <div>
        <!--Sub-heading -->
        <head>{sh2}</head>
        <p>{p8}</p>
        <p>{p9}</p>
        <p>{p10}</p>
        <p>{p11}</p>
        <p>{p12}</p>
        <p>{p13}</p>
        <p>{p14}</p>
        <p>{p15}</p>
        <p>{p16}</p>
        <p>{p17}</p>
        <p>{p18}</p>
        <p>{p19}</p>
        <p>{p20}</p>
        <p>{p21}</p>
        <p>{p22}</p>
      </div>
      <div>
        <!--Heading -->
        <head>{h2}</head>
        <p>{p23}</p>
        <p>{p24}</p>
        <p>{p25}</p>
        <p>{p26}</p>
        <p>{p27}</p>
        <p>{p28}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_142640.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
