# %%
# Import necessary libraries
from bs4 import BeautifulSoup  # BeautifulSoup is a library for parsing HTML and XML documents
import re  # The re module provides support for regular expressions

# Read the HOCR file
with open("/content/combined_hocr_141951.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()  # Read the content of the HOCR file

# Parse the HOCR content using BeautifulSoup
soup = BeautifulSoup(hocr_content, "html.parser")  # Create a BeautifulSoup object from the HOCR content

# Extract key information from the HOCR content

# Extract title text from bounding box "149 129 1017 213"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 149 129 1017 213" in value)
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)  # Extract text from the found div
else:
    title_text = ""  # Set title_text to empty string if the div is not found

# Extract date text from bounding box "443 1238 713 1270"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 443 1238 713 1270" in value)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b\d+\.\s\w+\s\d+\b", text)  # Search for a specific date format
    if match:
        date_text = match.group(0)  # Extract the matched date text
else:
    date_text = ""  # Set date_text to empty string if the div is not found

# Extract place names from bounding box "145 1412 1009 1453"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 145 1412 1009 1453" in value)
if div_place_tag:
    place_text = ""
    text = div_place_tag.get_text(strip=True)  # Extract text from the found div
    matches = re.findall(r'\bLeipzig\b|\bBerlin\b', text)  # Search for specific place names
    if matches:
        place_text = ' and '.join(matches)  # Join the found place names
else:
    place_text = ""  # Set place_text to empty string if the div is not found

# Extract organization name from bounding box "145 1412 1009 1453"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 145 1412 1009 1453" in value)
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)  # Extract text from the found div
    match = re.search(r"\b[A-Z]\.G\.[A-Z][a-z]+\b", text)  # Search for a specific organization name format
    if match:
        org_name_text = match.group(0)  # Extract the matched organization name
else:
    org_name_text = ""  # Set org_name_text to empty string if the div is not found

# Extract various text elements from different divs with specific bounding boxes
# These elements will be used to construct the TEI XML document later

# Extract heading 1 text from bounding box "162 376 1003 449"
div_h1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 162 376 1003 449" in value)
if div_h1:
    h1 = div_h1.get_text(strip=True)  # Extract text from the found div
else:
    h1 = ""  # Set h1 to empty string if the div is not found

# Extract subheading 1 text from bounding box "360 471 806 508"
div_sh1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 360 471 806 508" in value)
if div_sh1:
    sh1 = div_sh1.get_text(strip=True)  # Extract text from the found div
else:
    sh1 = ""  # Set sh1 to empty string if the div is not found

# Extract heading 2 text from bounding box "339 540 820 613"
div_h2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 339 540 820 613" in value)
if div_h2:
    h2 = div_h2.get_text(strip=True)  # Extract text from the found div
else:
    h2 = ""  # Set h2 to empty string if the div is not found

# Extract paragraph 1 text from bounding box "489 681 671 709"
div_p1 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 489 681 671 709" in value)
if div_p1:
    p1 = div_p1.get_text(strip=True)  # Extract text from the found div
else:
    p1 = ""  # Set p1 to empty string if the div is not found

# Extract paragraph 2 text from bounding box "209 735 955 826"
div_p2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 209 735 955 826" in value)
if div_p2:
    p2 = div_p2.get_text(strip=True)  # Extract text from the found div
else:
    p2 = ""  # Set p2 to empty string if the div is not found

# Extract paragraph 3 text from bounding box "247 899 914 1165"
div_p3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 247 899 914 1165" in value)
if div_p3:
    p3 = div_p3.get_text(strip=True)  # Extract text from the found div
else:
    p3 = ""  # Set p3 to empty string if the div is not found

# Extract paragraph 4 text from bounding box "443 1238 713 1270"
div_p4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 443 1238 713 1270" in value)
if div_p4:
    p4 = div_p4.get_text(strip=True)  # Extract text from the found div
else:
    p4 = ""  # Set p4 to empty string if the div is not found

# Extract paragraph 5 text from bounding box "145 1412 1009 1453"
div_p5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 145 1412 1009 1453" in value)
if div_p5:
    p5 = div_p5.get_text(strip=True)  # Extract text from the found div
else:
    p5 = ""  # Set p5 to empty string if the div is not found

# Extract paragraph 6 text from bounding box "481 1496 670 1535"
div_p6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 481 1496 670 1535" in value)
if div_p6:
    p6 = div_p6.get_text(strip=True)  # Extract text from the found div
else:
    p6 = ""  # Set p6 to empty string if the div is not found

# Extract heading 3 text from bounding box "370 138 871 221"
div_h3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 370 138 871 221" in value)
if div_h3:
    h3 = div_h3.get_text(strip=True)  # Extract text from the found div
else:
    h3 = ""  # Set h3 to empty string if the div is not found

# Extract heading 4 text from bounding box "477 227 764 276"
div_h4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 477 227 764 276" in value)
if div_h4:
    h4 = div_h4.get_text(strip=True)  # Extract text from the found div
else:
    h4 = ""  # Set h4 to empty string if the div is not found

# Extract paragraph 7 text from bounding box "190 281 1062 361"
div_p7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 190 281 1062 361" in value)
if div_p7:
    p7 = div_p7.get_text(strip=True)  # Extract text from the found div
else:
    p7 = ""  # Set p7 to empty string if the div is not found

# Extract heading 5 text from bounding box "191 398 879 475"
div_h5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 191 398 879 475" in value)
if div_h5:
    h5 = div_h5.get_text(strip=True)  # Extract text from the found div
else:
    h5 = ""  # Set h5 to empty string if the div is not found

# Extract paragraph 8 text from bounding box "191 474 1064 637"
div_p8 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 191 474 1064 637" in value)
if div_p8:
    p8 = div_p8.get_text(strip=True)  # Extract text from the found div
else:
    p8 = ""  # Set p8 to empty string if the div is not found

# Extract subheading 2 text from bounding box "195 655 384 684"
div_sh2 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 195 655 384 684" in value)
if div_sh2:
    sh2 = div_sh2.get_text(strip=True)  # Extract text from the found div
else:
    sh2 = ""  # Set sh2 to empty string if the div is not found

# Extract paragraph 9 text from bounding box "191 691 1061 756"
div_p9 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 191 691 1061 756" in value)
if div_p9:
    p9 = div_p9.get_text(strip=True)  # Extract text from the found div
else:
    p9 = ""  # Set p9 to empty string if the div is not found

# Extract heading 6 text from bounding box "427 763 827 805"
div_h6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 427 763 827 805" in value)
if div_h6:
    h6 = div_h6.get_text(strip=True)  # Extract text from the found div
else:
    h6 = ""  # Set h6 to empty string if the div is not found

# Extract paragraph 10 text from bounding box "195 807 1060 912"
div_p10 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 195 807 1060 912" in value)
if div_p10:
    p10 = div_p10.get_text(strip=True)  # Extract text from the found div
else:
    p10 = ""  # Set p10 to empty string if the div is not found

# Extract subheading 3 text from bounding box "196 925 341 961"
div_sh3 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 196 925 341 961" in value)
if div_sh3:
    sh3 = div_sh3.get_text(strip=True)  # Extract text from the found div
else:
    sh3 = ""  # Set sh3 to empty string if the div is not found

# Extract paragraph 11 text from bounding box "192 961 1074 1247"
div_p11 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 192 961 1074 1247" in value)
if div_p11:
    p11 = div_p11.get_text(strip=True)  # Extract text from the found div
else:
    p11 = ""  # Set p11 to empty string if the div is not found

# Extract paragraph 12 text from bounding box "197 1251 1061 1398"
div_p12 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 197 1251 1061 1398" in value)
if div_p12:
    p12 = div_p12.get_text(strip=True)  # Extract text from the found div
else:
    p12 = ""  # Set p12 to empty string if the div is not found

# Extract paragraph 13 text from bounding box "197 1400 760 1464"
div_p13 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 197 1400 760 1464" in value)
if div_p13:
    p13 = div_p13.get_text(strip=True)  # Extract text from the found div
else:
    p13 = ""  # Set p13 to empty string if the div is not found

# Extract paragraph 14 text from bounding box "153 131 1017 216"
div_p14 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 153 131 1017 216" in value)
if div_p14:
    p14 = div_p14.get_text(strip=True)  # Extract text from the found div
else:
    p14 = ""  # Set p14 to empty string if the div is not found

# Extract subheading 4 text from bounding box "152 247 337 330"
div_sh4 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 247 337 330" in value)
if div_sh4:
    sh4 = div_sh4.get_text(strip=True)  # Extract text from the found div
else:
    sh4 = ""  # Set sh4 to empty string if the div is not found

# Extract paragraph 15 text from bounding box "155 324 604 354"
div_p15 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 155 324 604 354" in value)
if div_p15:
    p15 = div_p15.get_text(strip=True)  # Extract text from the found div
else:
    p15 = ""  # Set p15 to empty string if the div is not found

# Extract subheading 5 text from bounding box "152 384 342 413"
div_sh5 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 384 342 413" in value)
if div_sh5:
    sh5 = div_sh5.get_text(strip=True)  # Extract text from the found div
else:
    sh5 = ""  # Set sh5 to empty string if the div is not found

# Extract paragraph 16 text from bounding box "155 427 480 462"
div_p16 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 155 427 480 462" in value)
if div_p16:
    p16 = div_p16.get_text(strip=True)  # Extract text from the found div
else:
    p16 = ""  # Set p16 to empty string if the div is not found

# Extract paragraph 17 text from bounding box "152 465 1016 528"
div_p17 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 465 1016 528" in value)
if div_p17:
    p17 = div_p17.get_text(strip=True)  # Extract text from the found div
else:
    p17 = ""  # Set p17 to empty string if the div is not found

# Extract paragraph 18 text from bounding box "151 534 1016 595"
div_p18 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 534 1016 595" in value)
if div_p18:
    p18 = div_p18.get_text(strip=True)  # Extract text from the found div
else:
    p18 = ""  # Set p18 to empty string if the div is not found

# Extract paragraph 19 text from bounding box "149 596 1017 687"
div_p19 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 149 596 1017 687" in value)
if div_p19:
    p19 = div_p19.get_text(strip=True)  # Extract text from the found div
else:
    p19 = ""  # Set p19 to empty string if the div is not found

# Extract paragraph 20 text from bounding box "149 688 1017 752"
div_p20 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 149 688 1017 752" in value)
if div_p20:
    p20 = div_p20.get_text(strip=True)  # Extract text from the found div
else:
    p20 = ""  # Set p20 to empty string if the div is not found

# Extract paragraph 21 text from bounding box "152 753 1015 817"
div_p21 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 753 1015 817" in value)
if div_p21:
    p21 = div_p21.get_text(strip=True)  # Extract text from the found div
else:
    p21 = ""  # Set p21 to empty string if the div is not found

# Extract paragraph 22 text from bounding box "152 818 520 855"
div_p22 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 818 520 855" in value)
if div_p22:
    p22 = div_p22.get_text(strip=True)  # Extract text from the found div
else:
    p22 = ""  # Set p22 to empty string if the div is not found

# Extract paragraph 23 text from bounding box "150 856 1015 921"
div_p23 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 150 856 1015 921" in value)
if div_p23:
    p23 = div_p23.get_text(strip=True)  # Extract text from the found div
else:
    p23 = ""  # Set p23 to empty string if the div is not found

# Extract paragraph 24 text from bounding box "151 922 654 1112"
div_p24 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 922 654 1112" in value)
if div_p24:
    p24 = div_p24.get_text(strip=True)  # Extract text from the found div
else:
    p24 = ""  # Set p24 to empty string if the div is not found

# Extract paragraph 25 text from bounding box "151 1114 1015 1178"
div_p25 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 1114 1015 1178" in value)
if div_p25:
    p25 = div_p25.get_text(strip=True)  # Extract text from the found div
else:
    p25 = ""  # Set p25 to empty string if the div is not found

# Extract paragraph 26 text from bounding box "151 1170 813 1292"
div_p26 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 1170 813 1292" in value)
if div_p26:
    p26 = div_p26.get_text(strip=True)  # Extract text from the found div
else:
    p26 = ""  # Set p26 to empty string if the div is not found

# Extract paragraph 27 text from bounding box "152 1293 1014 1357"
div_p27 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 1293 1014 1357" in value)
if div_p27:
    p27 = div_p27.get_text(strip=True)  # Extract text from the found div
else:
    p27 = ""  # Set p27 to empty string if the div is not found

# Extract paragraph 28 text from bounding box "152 1357 847 1396"
div_p28 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 152 1357 847 1396" in value)
if div_p28:
    p28 = div_p28.get_text(strip=True)  # Extract text from the found div
else:
    p28 = ""  # Set p28 to empty string if the div is not found

# Extract paragraph 29 text from bounding box "151 1396 1013 1461"
div_p29 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 151 1396 1013 1461" in value)
if div_p29:
    p29 = div_p29.get_text(strip=True)  # Extract text from the found div
else:
    p29 = ""  # Set p29 to empty string if the div is not found

# Extract paragraph 30 text from bounding box "176 129 906 242"
div_p30 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 129 906 242" in value)
if div_p30:
    p30 = div_p30.get_text(strip=True)  # Extract text from the found div
else:
    p30 = ""  # Set p30 to empty string if the div is not found

# Extract paragraph 31 text from bounding box "174 245 1042 334"
div_p31 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 174 245 1042 334" in value)
if div_p31:
    p31 = div_p31.get_text(strip=True)  # Extract text from the found div
else:
    p31 = ""  # Set p31 to empty string if the div is not found

# Extract paragraph 32 text from bounding box "176 337 992 413"
div_p32 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 337 992 413" in value)
if div_p32:
    p32 = div_p32.get_text(strip=True)  # Extract text from the found div
else:
    p32 = ""  # Set p32 to empty string if the div is not found

# Extract paragraph 33 text from bounding box "176 415 417 449"
div_p33 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 415 417 449" in value)
if div_p33:
    p33 = div_p33.get_text(strip=True)  # Extract text from the found div
else:
    p33 = ""  # Set p33 to empty string if the div is not found

# Extract heading 7 text from bounding box "428 482 1050 528"
div_h7 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 428 482 1050 528" in value)
if div_h7:
    h7 = div_h7.get_text(strip=True)  # Extract text from the found div
else:
    h7 = ""  # Set h7 to empty string if the div is not found

# Extract paragraph 34 text from bounding box "176 526 1042 732"
div_p34 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 176 526 1042 732" in value)
if div_p34:
    p34 = div_p34.get_text(strip=True)  # Extract text from the found div
else:
    p34 = ""  # Set p34 to empty string if the div is not found

# Extract subheading 6 text from bounding box "175 741 321 777"
div_sh6 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 175 741 321 777" in value)
if div_sh6:
    sh6 = div_sh6.get_text(strip=True)  # Extract text from the found div
else:
    sh6 = ""  # Set sh6 to empty string if the div is not found

# Extract paragraph 35 text from bounding box "173 781 1040 889"
div_p35 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 173 781 1040 889" in value)
if div_p35:
    p35 = div_p35.get_text(strip=True)  # Extract text from the found div
else:
    p35 = ""  # Set p35 to empty string if the div is not found

# Extract paragraph 36 text from bounding box "173 893 1039 1021"
div_p36 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 173 893 1039 1021" in value)
if div_p36:
    p36 = div_p36.get_text(strip=True)  # Extract text from the found div
else:
    p36 = ""  # Set p36 to empty string if the div is not found

# Extract paragraph 37 text from bounding box "172 1026 1054 1298"
div_p37 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 172 1026 1054 1298" in value)
if div_p37:
    p37 = div_p37.get_text(strip=True)  # Extract text from the found div
else:
    p37 = ""  # Set p37 to empty string if the div is not found

# Extract paragraph 38 text from bounding box "175 1316 599 1459"
div_p38 = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 175 1316 599 1459" in value)
if div_p38:
    p38 = div_p38.get_text(strip=True)  # Extract text from the found div
else:
    p38 = ""  # Set p38 to empty string if the div is not found

# Construct the TEI XML document using the extracted information

# Define the TEI XML structure with extracted data
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
      <div>
        <!-- Heading -->
        <head>{h1}</head>
        <!-- Subtext -->
        <head>{sh1}</head>
        <!-- Heading -->
        <head>{h2}</head>
        <p>{p1}</p>
        <p>{p2}</p>
        <p>{p3}</p>
        <p>{p4}</p>
        <p>{p5}</p>
        <p>{p6}</p>
      </div>
      <div>
        <!-- Heading -->
        <head>{h3}</head>
        <!-- Heading -->
        <head>{h4}</head>
        <p>{p7}</p>
        <!-- Heading -->
        <head>{h5}</head>
        <p>{p8}</p>
        <!-- Sub-heading -->
        <head>{sh2}</head>
        <p>{p9}</p>
        <!-- Heading -->
        <head>{h6}</head>
        <p>{p10}</p>
        <!-- Sub-heading -->
        <head>{sh3}</head>
        <p>{p11}</p>
        <p>{p12}</p>
        <p>{p13}</p>
      </div>
      <div>
        <p>{p14}</p>
        <!-- Sub-heading -->
        <head>{sh4}</head>
        <p>{p15}</p>
        <!-- Sub-heading -->
        <head>{sh5}</head>
        <p>{p16}</p>
        <p>{p17}</p>
        <p>{p18}</p>
        <p>{p19}</p>
        <p>{p20}</p>
        <p>{p21}</p>
        <p>{p22}</p>
        <p>{p23}</p>
        <p>{p24}</p>
        <p>{p25}</p>
        <p>{p26}</p>
        <p>{p27}</p>
        <p>{p28}</p>
        <p>{p29}</p>
      </div>
      <div>
        <p>{p30}</p>
        <p>{p31}</p>
        <p>{p32}</p>
        <p>{p33}</p>
        <!-- Heading -->
        <head>{h7}</head>
        <p>{p34}</p>
        <!-- Sub-heading -->
        <head>{sh6}</head>
        <p>{p35}</p>
        <p>{p36}</p>
        <p>{p37}</p>
        <p>{p38}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write the TEI XML document to a file
with open("final_output_141951.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)  # Write the TEI XML document content to the file
